# %% [markdown]
# # Web-crawler for collecting banks information

# %% [markdown]
# ### The case

# %% [markdown]
# Online payment processing company has a number of banks in different countries they work with. They need to collect a database with full information avaliable on web about each bank. As a source of information <i>wise.com</i> will be used.
#
# For each country from input data we scrape all banks within the country and get the following table fields:
# - general swift code
# - branch name
# - branch address
# - branch code
# - bank name
# - city
# - country
#
# Then, tables will be merged by swift to get only those countries, in which the company has banks and accounts.
#
# *The last section of code is devoted to merging banks with swifts from the web with banks, that were given without swifts as input. Unfortunately due to absence of standard names in input data, some part of the work was done manually. Ignore that section. The main focus of the notebook is parsing.

# %%
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup
from selenium import webdriver

from random import randint
import time

import nltk
import re

# %% [markdown]
# Loading and preparing data

# %%
# summary sheet contains swifts
bic_summary = (pd.read_excel('Account_Summary_v3.xlsx', sheet_name='Summary')
               .iloc[:-1, :]
               .replace(['England', 'Kenia'], ['United Kingdom', 'Kenya'])
              )

# where swifts are missing we put "n/a"
bic_summary.loc[:, 'swift_short'] = bic_summary.loc[:, 'swift_short'].fillna('n/a')

# do forward fill for region and country
bic_summary.loc[:, ['Region', 'Bank Country']] = \
    bic_summary.loc[:, ['Region', 'Bank Country']].ffill()

# create a unique country + bank_name key to merge summary with detail
bic_summary['merge_key'] = bic_summary['Bank Country'] + bic_summary['Bank Name']


# detail contains detailed information on bank,
# including separate rows for each cash type and currency account for each bank
bic_detail = (pd.read_excel('Account_Summary_v3.xlsx', sheet_name='Detail')
              .iloc[:-1, :]
              .replace(['England', 'Kenia'], ['United Kingdom', 'Kenya'])
             )

# do forward fill for region, country, bank name and cash type
bic_detail.loc[:, ['Region', 'Bank Country', 'Bank Name', 'Cash Type']] = \
    bic_detail.loc[:, ['Region', 'Bank Country', 'Bank Name', 'Cash Type']].ffill()

# create the same key for merge in detail as well
bic_detail['merge_key'] = bic_detail['Bank Country'] + bic_detail['Bank Name']

# %%
bic_summary
# Out:
#     Region    Bank Country  # of banks by country  # of banks running  \
# 0     EMEA        Bulgaria                    1.0                 1.0
# 1     EMEA         Croatia                    1.0                 2.0
# 2     EMEA  Czech Republic                    9.0                 3.0
# 3     EMEA  Czech Republic                    NaN                 4.0
# 4     EMEA  Czech Republic                    NaN                 5.0
# ..     ...             ...                    ...                 ...
# 105  LATAM            Peru                    NaN               106.0
# 106  LATAM           Spain                    2.0               107.0
# 107  LATAM           Spain                    NaN               108.0
# 108  LATAM   United States                    2.0               109.0
# 109  LATAM   United States                    NaN               110.0
#
#                                Bank Name  # of accounts swift_short  \
# 0                   UniCredit Bulbank AD              1    UNCRBGSF
# 1                       Zagrebacka Banka              2    ZABAHR2X
# 2                 Česká spořitelna, a.s.              9    GIBACZPX
# 3    Československá obchodní banka, a.s.              3    CEKOCZPP
# 4                        Fio banka, a.s.              2    FIOBCZPP
# ..                                   ...            ...         ...
# 105                   Banco de la Nacion              1    BANCPEPL
# 106                 Banco Santander S.A.              2    BSCHESMM
# 107                         Pershing LLC              1   PRSHUS33
# 108                       Citibank, N.A.              1    CITIUS33
# 109      Morgan Stanley Smith Barney LLC              1    DWRIUS3A
#
#                                              merge_key
# 0                         BulgariaUniCredit Bulbank AD
# 1                              CroatiaZagrebacka Banka
# 2                 Czech RepublicČeská spořitelna, a.s.
# 3    Czech RepublicČeskoslovenská obchodní banka, a.s.
# 4                        Czech RepublicFio banka, a.s.
# ..                                                 ...
# 105                             PeruBanco de la Nacion
# 106                          SpainBanco Santander S.A.
# 107                                  SpainPershing LLC
# 108                        United StatesCitibank, N.A.
# 109       United StatesMorgan Stanley Smith Barney LLC
#
# [110 rows x 8 columns]

# %%
bic_detail
# Out:
#     Region    Bank Country  # of banks by country  \
# 0     EMEA        Bulgaria                    1.0
# 1     EMEA         Croatia                    1.0
# 2     EMEA  Czech Republic                    9.0
# 3     EMEA  Czech Republic                    NaN
# 4     EMEA  Czech Republic                    NaN
# ..     ...             ...                    ...
# 249  LATAM           Spain                    2.0
# 250  LATAM           Spain                    NaN
# 251  LATAM           Spain                    NaN
# 252  LATAM   United States                    2.0
# 253  LATAM   United States                    NaN
#
#                                Bank Name      Cash Type Currency       BIC  \
# 0                   UniCredit Bulbank AD  Merchant Cash      BGN  UNCRBGSF
# 1                       Zagrebacka Banka  Merchant Cash      HRK  ZABAHR2X
# 2                 Česká spořitelna, a.s.  Merchant Cash      CZK  GIBACZPX
# 3    Československá obchodní banka, a.s.  Merchant Cash      CZK  CEKOCZPP
# 4                        Fio banka, a.s.  Merchant Cash      CZK  FIOBCZPP
# ..                                   ...            ...      ...       ...
# 249                 Banco Santander S.A.     Trade Cash      EUR       NaN
# 250                 Banco Santander S.A.     Trade Cash      USD       NaN
# 251                         Pershing LLC     Trade Cash      USD       NaN
# 252                       Citibank, N.A.     Trade Cash      USD       NaN
# 253      Morgan Stanley Smith Barney LLC     Trade Cash      USD       NaN
#
#      # of accounts                                          merge_key
# 0                1                       BulgariaUniCredit Bulbank AD
# 1                2                            CroatiaZagrebacka Banka
# 2                9               Czech RepublicČeská spořitelna, a.s.
# 3                3  Czech RepublicČeskoslovenská obchodní banka, a.s.
# 4                2                      Czech RepublicFio banka, a.s.
# ..             ...                                                ...
# 249              1                          SpainBanco Santander S.A.
# 250              1                          SpainBanco Santander S.A.
# 251              1                                  SpainPershing LLC
# 252              1                        United StatesCitibank, N.A.
# 253              1       United StatesMorgan Stanley Smith Barney LLC
#
# [254 rows x 9 columns]

# %%
# do left join, so each bank in detail would have a swift
# for now we assume, that swifts for each bank are the same if we are talking about cash types and currency
detail_with_swifts = \
    (bic_detail.merge(bic_summary.loc[:, ['merge_key', 'swift_short']],
                     on='merge_key',
                     how='left')
     .drop('merge_key', axis=1)
    )

# do forward fill to assign swift to each bank account
# detail_with_swifts.loc[:, ['Region', 'Bank Country', 'swift_short']] = \
#     detail_with_swifts.loc[:, ['Region', 'Bank Country', 'swift_short']].ffill()

# %%
detail_with_swifts
# Out:
#     Region    Bank Country  # of banks by country  \
# 0     EMEA        Bulgaria                    1.0
# 1     EMEA         Croatia                    1.0
# 2     EMEA  Czech Republic                    9.0
# 3     EMEA  Czech Republic                    NaN
# 4     EMEA  Czech Republic                    NaN
# ..     ...             ...                    ...
# 249  LATAM           Spain                    2.0
# 250  LATAM           Spain                    NaN
# 251  LATAM           Spain                    NaN
# 252  LATAM   United States                    2.0
# 253  LATAM   United States                    NaN
#
#                                Bank Name      Cash Type Currency       BIC  \
# 0                   UniCredit Bulbank AD  Merchant Cash      BGN  UNCRBGSF
# 1                       Zagrebacka Banka  Merchant Cash      HRK  ZABAHR2X
# 2                 Česká spořitelna, a.s.  Merchant Cash      CZK  GIBACZPX
# 3    Československá obchodní banka, a.s.  Merchant Cash      CZK  CEKOCZPP
# 4                        Fio banka, a.s.  Merchant Cash      CZK  FIOBCZPP
# ..                                   ...            ...      ...       ...
# 249                 Banco Santander S.A.     Trade Cash      EUR       NaN
# 250                 Banco Santander S.A.     Trade Cash      USD       NaN
# 251                         Pershing LLC     Trade Cash      USD       NaN
# 252                       Citibank, N.A.     Trade Cash      USD       NaN
# 253      Morgan Stanley Smith Barney LLC     Trade Cash      USD       NaN
#
#      # of accounts swift_short
# 0                1    UNCRBGSF
# 1                2    ZABAHR2X
# 2                9    GIBACZPX
# 3                3    CEKOCZPP
# 4                2    FIOBCZPP
# ..             ...         ...
# 249              1    BSCHESMM
# 250              1    BSCHESMM
# 251              1   PRSHUS33
# 252              1    CITIUS33
# 253              1    DWRIUS3A
#
# [254 rows x 9 columns]

# %% [markdown]
# ## Scraping wise.com by country

# %% [markdown]
# ### Retrieve proxies

# %% [markdown]
# To avoid being blocked while parsing, we'll use IP-rotation. Proxies are retrieved from <i>sslproxies.org</i>

# %%
def get_proxies(url_proxy):
    
    html = requests.get(url_proxy).text
    soup = BeautifulSoup(html, 'html.parser')

    return soup.find('textarea').text.split('\n')[3:-1]
    
    
url_proxy = 'https://sslproxies.org/'
proxies = get_proxies(url_proxy)

# %% [markdown]
# ### Create functions for parsing

# %% [markdown]
# Function generates request url for a country and a page given as input

# %%
def generate_url(country, page):
    if page == 1:
        return f'https://wise.com/us/swift-codes/countries/{country}'
    return f'https://wise.com/us/swift-codes/countries/{country}?page={page}'

# %%
generate_url('czech-republic', 2)
# Out:
# 'https://wise.com/us/swift-codes/countries/czech-republic?page=2'

# %% [markdown]
# Function gets banks' hrefs avaliable for the country on a specific page

# %%
def get_country_page_hrefs(country, page, proxy):
    
    html = requests.get(generate_url(country, page),
                        proxies = {"http://": proxy, "https://": proxy}).text
    soup = BeautifulSoup(html, 'html.parser')
    
    bank_hrefs = []
    
    for row in soup.find_all('tr'):
        
        if row.find('td'):
            bank_hrefs.append(row.find('td').find('a')['href'])
    
    return bank_hrefs

# %%
get_country_page_hrefs('czech-republic', 2, proxies[0])
# Out:
# ['/us/swift-codes/countries/czech-republic/bank-of-communications-co-ltd-prague-branch-odstepny-zavod',
#  '/us/swift-codes/countries/czech-republic/banka-creditas',
#  '/us/swift-codes/countries/czech-republic/barigol-management-s-r-o',
#  '/us/swift-codes/countries/czech-republic/bnp-paribas-s-a-pobocka-ceska-republika',
#  '/us/swift-codes/countries/czech-republic/centralni-depozitar-cennych-papiru-a-s']

# %% [markdown]
# Function gets all banks' hrefs for a given country

# %%
def get_country_bank_hrefs(country, proxies):
    
    page = 1
    
    if page == 1 or page % 10 == 0:
        proxy = proxies[randint(0, 99)]
    
    store_country = []
    
    while True:
        
        country_hrefs = get_country_page_hrefs(country, page, proxy)
        
        if country_hrefs:
            store_country.extend(country_hrefs)
        else:
            break
        
        page += 1
            
    return pd.DataFrame({'hrefs': store_country})

# %%
# get_country_bank_hrefs('czech-republic', proxies)

# %% [markdown]
# By iterating through list of unique countries from input xlsx file, we get all banks' hrefs and store them in the dataframe with country specified.

# %%
store_hrefs = []

for country in ['-'.join(c.lower().split(' ')) for c in bic_data['Bank Country'].unique()]:
    
    country_hrefs = get_country_bank_hrefs(country, proxies)
    country_hrefs['country'] = country
    
    store_hrefs.append(country_hrefs)
    print('loaded hrefs for {}'.format(country))
    

hrefs_df = pd.concat(store_hrefs)
# Out:
# loaded hrefs for bulgaria
# loaded hrefs for croatia
# loaded hrefs for czech-republic
# loaded hrefs for united-kingdom
# loaded hrefs for hungary
# loaded hrefs for israel
# loaded hrefs for kenya
# loaded hrefs for netherlands
# loaded hrefs for nigeria
# loaded hrefs for poland
# loaded hrefs for romania
# loaded hrefs for russia
# loaded hrefs for slovakia
# loaded hrefs for south-africa
# loaded hrefs for turkey
# loaded hrefs for argentina
# loaded hrefs for chile
# loaded hrefs for colombia
# loaded hrefs for mexico
# loaded hrefs for panama
# loaded hrefs for peru
# loaded hrefs for spain
# loaded hrefs for united-states

# %%
# write hrefs to csv to save the results
hrefs_df.to_csv('pre_bank_hrefs.csv')

# %%
hrefs_df = pd.read_csv('pre_bank_hrefs.csv', index_col=0)

# %%
hrefs_df
# Out:
#                                                   hrefs        country
# 0     /us/swift-codes/countries/bulgaria/allianz-ban...       bulgaria
# 1     /us/swift-codes/countries/bulgaria/bnp-paribas...       bulgaria
# 2          /us/swift-codes/countries/bulgaria/borica-ad       bulgaria
# 3     /us/swift-codes/countries/bulgaria/bulgarian-d...       bulgaria
# 4     /us/swift-codes/countries/bulgaria/bulgarian-n...       bulgaria
# ...                                                 ...            ...
# 1286  /us/swift-codes/countries/united-states/xerox-...  united-states
# 1287  /us/swift-codes/countries/united-states/yisrae...  united-states
# 1288  /us/swift-codes/countries/united-states/zf-aut...  united-states
# 1289  /us/swift-codes/countries/united-states/zions-...  united-states
# 1290  /us/swift-codes/countries/united-states/zurich...  united-states
#
# [3985 rows x 2 columns]

# %% [markdown]
# For each bank href <i>wise.com</i> has several banks - different branches within the country. The following function retrieves information

# %%
def get_bank_info(country, href, proxy):
    
    request_url = f'https://wise.com{href}'
    
    html = requests.get(request_url,
                        proxies = {"http://": proxy, "https://": proxy}).text
    soup = BeautifulSoup(html, 'html.parser')
    
    cells = soup.find_all('li', attrs = {'class': 'list-group-item'})
    
    swifts, bank_names = [], []
    
    for cell in cells:
        
        raw_swift = cell.find('a')['href']
        swift = raw_swift[raw_swift.find('codes/') + 6:]
        bank_name = cell.find('small').find('span', attrs = {'class': 'd-block'}).text
        
        swifts.append(swift)
        bank_names.append(bank_name)

    df = pd.DataFrame({'swift': swifts, 'name_from_wise': bank_names})
    df['bank_country'] = country
    
    return df

# %%
get_bank_info(hrefs_df.country.iloc[2], hrefs_df.hrefs.iloc[2], proxies[0])
# Out:
#          swift name_from_wise bank_country
# 0  BSBGBGSFXXX      BORICA AD     bulgaria
# 1  BSBGBGSFIOP      BORICA AD     bulgaria

# %%
store_info = []

for idx, (country, href) in enumerate(zip(hrefs_df.country, hrefs_df.hrefs)):
    
    if idx % 10 == 0:
        proxy = proxies[randint(0, 99)]
    
    store_info.append(get_bank_info(country, href, proxy))
    
    if idx % 250 == 0:
        print(f'processed {idx} href(s)')
    
    
banks_info_df = pd.concat(store_info)
# Out:
# processed 0 href(s)
# processed 250 href(s)
# processed 500 href(s)
# processed 750 href(s)
# processed 1000 href(s)
# processed 1250 href(s)
# processed 1500 href(s)
# processed 1750 href(s)
# processed 2000 href(s)
# processed 2250 href(s)
# processed 2500 href(s)
# processed 2750 href(s)
# processed 3000 href(s)
# processed 3250 href(s)
# processed 3500 href(s)
# processed 3750 href(s)

# %%
banks_info_df['bank_country'] = \
    banks_info_df.bank_country.apply(lambda x: ' '.join(x.split('-')))

# %%
banks_info_df.to_csv('banks_info_data.csv')

# %%
banks_info_df = pd.read_csv('banks_info_data.csv', index_col=0).drop_duplicates().reset_index(drop=True)

# %%
banks_info_df
# Out:
#             swift                     name_from_wise   bank_country
# 0     BUINBGSFXXX           ALLIANZ BANK BULGARIA AD       bulgaria
# 1     BNPABGSXXXX      BNP PARIBAS S.A.-SOFIA BRANCH       bulgaria
# 2     BSBGBGSFXXX                          BORICA AD       bulgaria
# 3     BSBGBGSFIOP                          BORICA AD       bulgaria
# 4     NASBBGSFXXX      BULGARIAN DEVELOPMENT BANK AD       bulgaria
# ...           ...                                ...            ...
# 5954  ZFNBUS55SLC          ZIONS BANCORPORATION N.A.  united states
# 5955  ZFNBUS55SEA          ZIONS BANCORPORATION N.A.  united states
# 5956  ZURIUS44FAR  ZURICH AMERICAN INSURANCE COMPANY  united states
# 5957  ZURIUS44XXX  ZURICH AMERICAN INSURANCE COMPANY  united states
# 5958  ZURIUS44ZNA  ZURICH AMERICAN INSURANCE COMPANY  united states
#
# [5959 rows x 3 columns]

# %%
def get_full_bank_info(swift, proxy):
    
    request_url = f'https://wise.com/us/swift-codes/{swift}'
    
    html = requests.get(request_url,
                        proxies = {"http://": proxy, "https://": proxy}).text
    soup = BeautifulSoup(html, 'html.parser')
    
    row_names, row_values = [], []
    
    if soup.find('table') is None:
        return
#         return pd.DataFrame({'Swift code (8 characters)': [],
#                              'Branch name': [],
#                              'Branch address': [],
#                              'Branch code': [],
#                              ''
#                             })
        
        
    for row in soup.find('table').find_all('tr')[1:]:
        
        row_names.append(row.find('th').text)
        
        try:
            row_values.append(row.find('td').text)
            
        except AttributeError:
            row_values.append(row.find('td').find('a').text)
    
    return pd.DataFrame(row_values, row_names).T

# %%
get_full_bank_info('BUINBGSFXXX', proxies[0])
# Out:
#   Swift code (8 characters)               Branch name  \
# 0                  BUINBGSF  ALLIANZ BANK BULGARIA AD
#
#               Branch address Branch code                     Bank name   City  \
# 0  79 MARIA LOUISA BOULEVARD         XXX  \nALLIANZ BANK BULGARIA AD\n  SOFIA
#
#         Country
# 0  \nBulgaria\n

# %%
store_info = []

for idx, swift in enumerate(banks_info_df.swift.iloc[1100:], start=1100):
    
    if idx % 10 == 0:
        proxy = proxies[randint(0, 99)]
        
    store_info.append(get_full_bank_info(swift, proxy))
        
    if idx % 100 == 0:
        print(f'processed {idx} href(s)')
        
    
banks_full_info = pd.concat(store_info)
# Out:
# processed 1100 href(s)
# processed 1200 href(s)
# processed 1300 href(s)
# processed 1400 href(s)
# processed 1500 href(s)
# processed 1600 href(s)
# processed 1700 href(s)
# processed 1800 href(s)
# processed 1900 href(s)
# processed 2000 href(s)
# processed 2100 href(s)
# processed 2200 href(s)
# processed 2300 href(s)
# processed 2400 href(s)
# processed 2500 href(s)
# processed 2600 href(s)
# processed 2700 href(s)
# processed 2800 href(s)
# processed 2900 href(s)
# processed 3000 href(s)
# processed 3100 href(s)
# processed 3200 href(s)
# processed 3300 href(s)
# processed 3400 href(s)
# processed 3500 href(s)
# processed 3600 href(s)
# processed 3700 href(s)
# processed 3800 href(s)
# processed 3900 href(s)
# processed 4000 href(s)
# processed 4100 href(s)
# processed 4200 href(s)
# processed 4300 href(s)
# processed 4400 href(s)
# processed 4500 href(s)
# processed 4600 href(s)
# processed 4700 href(s)
# processed 4800 href(s)
# processed 4900 href(s)
# processed 5000 href(s)
# processed 5100 href(s)
# processed 5200 href(s)
# processed 5300 href(s)
# processed 5400 href(s)
# processed 5500 href(s)
# processed 5600 href(s)
# processed 5700 href(s)
# processed 5800 href(s)
# processed 5900 href(s)
# processed 6000 href(s)
# processed 6100 href(s)
# processed 6200 href(s)

# %%
banks_full_info = pd.concat(store_info).drop_duplicates().reset_index(drop=True)

# %%
banks_full_info.columns
# Out:
# Index(['Swift code (8 characters)', 'Branch name', 'Branch address',
#        'Branch code', 'Bank name', 'City', 'Country'],
#       dtype='object')

# %%
banks_full_info.loc[:, ['Bank name', 'Country']] = \
    banks_full_info.loc[:, ['Bank name', 'Country']].applymap(lambda x: x.strip())

banks_full_info.loc[:, 'swift_full'] = \
    banks_full_info['Swift code (8 characters)'] + banks_full_info['Branch code']

banks_full_info = (banks_full_info.rename({'Swift code (8 characters)': 'swift_short',
                                          'Branch name': 'branch_name',
                                          'Branch address': 'branch_address',
                                          'Branch code': 'branch_code',
                                          'Bank name': 'bank_name',
                                          'City': 'city',
                                          'Country': 'country'
                                         }, axis=1)
                   .loc[:, ['country', 'city', 'bank_name', 'branch_name',
                            'branch_code', 'branch_address', 'swift_short', 'swift_full']]
                  )

# %%
banks_full_info
# Out:
#             country            city                          bank_name  \
# 0          Bulgaria           SOFIA           ALLIANZ BANK BULGARIA AD
# 1          Bulgaria           SOFIA      BNP PARIBAS S.A.-SOFIA BRANCH
# 2          Bulgaria           SOFIA                          BORICA AD
# 3          Bulgaria           SOFIA                          BORICA AD
# 4          Bulgaria           SOFIA      BULGARIAN DEVELOPMENT BANK AD
# ...             ...             ...                                ...
# 5953  United States  SALT LAKE CITY          ZIONS BANCORPORATION N.A.
# 5954  United States         SEATTLE          ZIONS BANCORPORATION N.A.
# 5955  United States      SCHAUMBURG  ZURICH AMERICAN INSURANCE COMPANY
# 5956  United States      SCHAUMBURG  ZURICH AMERICAN INSURANCE COMPANY
# 5957  United States      SCHAUMBURG  ZURICH AMERICAN INSURANCE COMPANY
#
#                             branch_name branch_code  \
# 0              ALLIANZ BANK BULGARIA AD         XXX
# 1         BNP PARIBAS S.A.-SOFIA BRANCH         XXX
# 2                             BORICA AD         XXX
# 3                             BORICA AD         IOP
# 4         BULGARIAN DEVELOPMENT BANK AD         XXX
# ...                                 ...         ...
# 5953          ZIONS BANCORPORATION N.A.         SLC
# 5954          ZIONS BANCORPORATION N.A.         SEA
# 5955  ZURICH AMERICAN INSURANCE COMPANY         FAR
# 5956  ZURICH AMERICAN INSURANCE COMPANY         XXX
# 5957  ZURICH AMERICAN INSURANCE COMPANY         ZNA
#
#                     branch_address swift_short   swift_full
# 0        79 MARIA LOUISA BOULEVARD    BUINBGSF  BUINBGSFXXX
# 1         2, TZAR OSVOBODITEL BLVD    BNPABGSX  BNPABGSXXXX
# 2         41, TZAR BORIS III BLVD.    BSBGBGSF  BSBGBGSFXXX
# 3                                     BSBGBGSF  BSBGBGSFIOP
# 4         1, DYAKON IGNATIY STREET    NASBBGSF  NASBBGSFXXX
# ...                            ...         ...          ...
# 5953  1 SOUTH MAIN STREET, FLOOR 4    ZFNBUS55  ZFNBUS55SLC
# 5954              601 UNION STREET    ZFNBUS55  ZFNBUS55SEA
# 5955            1400 AMERICAN LANE    ZURIUS44  ZURIUS44FAR
# 5956               1299 ZURICH WAY    ZURIUS44  ZURIUS44XXX
# 5957            1400 AMERICAN LANE    ZURIUS44  ZURIUS44ZNA
#
# [5958 rows x 8 columns]

# %%
# banks_full_info.to_csv('banks_full_info.csv', index=False)

# %%
# banks_full_info.to_excel('banks_full_info.xlsx', index=False)

# %% [markdown]
# ### Merging all banks database with detail table
#
# Some of banks that were available on the website didn't appear in the resulting file. Check all missing swifts once again with requests by BIC.

# %%
banks_full_info = pd.read_csv('banks_full_info.csv')

# %%
banks_full_info[banks_full_info.swift_full.str.contains('ZABAHR2X')]
# Out:
#     country           city            bank_name          branch_name  \
# 72  Croatia         OSIJEK  ZAGREBACKA BANKA DD  ZAGREBACKA BANKA DD
# 73  Croatia          POREC  ZAGREBACKA BANKA DD  ZAGREBACKA BANKA DD
# 74  Croatia           PULA  ZAGREBACKA BANKA DD  ZAGREBACKA BANKA DD
# 75  Croatia       MAKARSKA  ZAGREBACKA BANKA DD  ZAGREBACKA BANKA DD
# 76  Croatia  NOVA GRADISKA  ZAGREBACKA BANKA DD  ZAGREBACKA BANKA DD
#
#    branch_code           branch_address swift_short   swift_full
# 72         OSI            TRG SLOBODE 4    ZABAHR2X  ZABAHR2XOSI
# 73         POR         OBALA M. TITA 8B    ZABAHR2X  ZABAHR2XPOR
# 74         PUL              LAGINJINA 1    ZABAHR2X  ZABAHR2XPUL
# 75         MAK             JADRANSKA 1A    ZABAHR2X  ZABAHR2XMAK
# 76         NOV  TRG KRALJA TOMISLAVA 13    ZABAHR2X  ZABAHR2XNOV

# %%
detail_with_swift_addr = \
    (detail_with_swifts.merge(banks_full_info.query('branch_code == "XXX"')
                              .loc[:, ['bank_name', 'branch_name', 'city',
                                       'branch_code', 'branch_address', 'swift_short', 'swift_full']],
                             on='swift_short',
                             how='left'
                            )
    )

# %%
detail_with_swift_addr.to_csv('detail_with_swift_with_missing_addr.csv')

# %% [markdown]
# ### Getting missing main branches addresses

# %%
detail_with_swift_addr = pd.read_csv('detail_with_swift_with_missing_addr.csv', index_col=0)

# %%
missing_address = \
    detail_with_swift_addr[detail_with_swift_addr.city.isnull()]

# %%
detail_with_swift_addr
# Out:
#     Region    Bank Country  # of banks by country  \
# 0     EMEA        Bulgaria                    1.0
# 1     EMEA         Croatia                    1.0
# 2     EMEA  Czech Republic                    9.0
# 3     EMEA  Czech Republic                    NaN
# 4     EMEA  Czech Republic                    NaN
# ..     ...             ...                    ...
# 249  LATAM           Spain                    2.0
# 250  LATAM           Spain                    NaN
# 251  LATAM           Spain                    NaN
# 252  LATAM   United States                    2.0
# 253  LATAM   United States                    NaN
#
#                                Bank Name      Cash Type Currency       BIC  \
# 0                   UniCredit Bulbank AD  Merchant Cash      BGN  UNCRBGSF
# 1                       Zagrebacka Banka  Merchant Cash      HRK  ZABAHR2X
# 2                 Česká spořitelna, a.s.  Merchant Cash      CZK  GIBACZPX
# 3    Československá obchodní banka, a.s.  Merchant Cash      CZK  CEKOCZPP
# 4                        Fio banka, a.s.  Merchant Cash      CZK  FIOBCZPP
# ..                                   ...            ...      ...       ...
# 249                 Banco Santander S.A.     Trade Cash      EUR       NaN
# 250                 Banco Santander S.A.     Trade Cash      USD       NaN
# 251                         Pershing LLC     Trade Cash      USD       NaN
# 252                       Citibank, N.A.     Trade Cash      USD       NaN
# 253      Morgan Stanley Smith Barney LLC     Trade Cash      USD       NaN
#
#      # of accounts swift_short                            bank_name  \
# 0                1    UNCRBGSF                                  NaN
# 1                2    ZABAHR2X                                  NaN
# 2                9    GIBACZPX                CESKA SPORITELNA A.S.
# 3                3    CEKOCZPP  CESKOSLOVENSKA OBCHODNI BANKA, A.S.
# 4                2    FIOBCZPP                      FIO BANKA, A.S.
# ..             ...         ...                                  ...
# 249              1    BSCHESMM                                  NaN
# 250              1    BSCHESMM                                  NaN
# 251              1   PRSHUS33                                   NaN
# 252              1    CITIUS33                                  NaN
# 253              1    DWRIUS3A      MORGAN STANLEY SMITH BARNEY LLC
#
#                              branch_name      city branch_code  \
# 0                                    NaN       NaN         NaN
# 1                                    NaN       NaN         NaN
# 2                  CESKA SPORITELNA A.S.    PRAGUE         XXX
# 3    CESKOSLOVENSKA OBCHODNI BANKA, A.S.    PRAGUE         XXX
# 4                        FIO BANKA, A.S.    PRAGUE         XXX
# ..                                   ...       ...         ...
# 249                                  NaN       NaN         NaN
# 250                                  NaN       NaN         NaN
# 251                                  NaN       NaN         NaN
# 252                                  NaN       NaN         NaN
# 253      MORGAN STANLEY SMITH BARNEY LLC  PURCHASE         XXX
#
#                                    branch_address   swift_full
# 0                                             NaN          NaN
# 1                                             NaN          NaN
# 2                                  OLBRACHTOVA 62  GIBACZPXXXX
# 3                                RADLICKA 333/150  CEKOCZPPXXX
# 4    MILLENNIUM PLAZA, FLOOR 1, V CELNICI 1028/10  FIOBCZPPXXX
# ..                                            ...          ...
# 249                                           NaN          NaN
# 250                                           NaN          NaN
# 251                                           NaN          NaN
# 252                                           NaN          NaN
# 253                       2000 WESTCHESTER AVENUE  DWRIUS3AXXX
#
# [254 rows x 15 columns]

# %%
missing_address.swift_short.unique()
# Out:
# array(['UNCRBGSF', 'ZABAHR2X', nan, 'POALILIT', 'KCBLKENX', 'INGBNL2A',
#        'UNAFNGLA', 'EBOSPLPW', 'BREXPLPW', 'BPKOPLPW', 'BTRLRO22',
#        'VTBRRUM2', 'ABSAZAJJ', 'SBZAZAJJ', 'ASYATRIS', 'FNNBTRIS',
#        'TEBUTRIS', 'TGBATRIS', 'TRHBTR2A', 'TVBATR2A', 'YAPITRIS',
#        'BBOGCOBB', 'COLOCOBM', 'BNMXMXMM', 'BSCHESMM', 'PRSHUS33\xa0',
#        'CITIUS33'], dtype=object)

# %%
store_missing = []

for swift in missing_address.swift_short.unique():
    
    if isinstance(swift, str):
        
        try:
            store_missing.append(get_full_bank_info(swift + 'XXX', proxies[1]))
        except AttributeError:
            store_missing.append(pd.DataFrame({}))
    
    
retrieved_missing = pd.concat(store_missing)

# %%
retrieved_missing
# Out:
#   Swift code (8 characters)                                Branch name  \
# 0                  UNCRBGSF                       UNICREDIT BULBANK AD
# 0                  ZABAHR2X                        ZAGREBACKA BANKA DD
# 0                  POALILIT                         BANK HAPOALIM B.M.
# 0                  KCBLKENX                     KCB BANK KENYA LIMITED
# 0                  INGBNL2A                              ING BANK N.V.
# 0                  UNAFNGLA                 UNITED BANK FOR AFRICA PLC
# 0                  EBOSPLPW               BANK OCHRONY SRODOWISKA S.A.
# 0                  BREXPLPW        MBANK S.A. (FORMERLY BRE BANK S.A.)
# 0                  BPKOPLPW                       PKO BANK POLSKI S.A.
# 0                  BTRLRO22                    BANCA TRANSILVANIA S.A.
# 0                  ABSAZAJJ                          ABSA BANK LIMITED
# 0                  SBZAZAJJ  STANDARD BANK OF SOUTH AFRICA LIMITED,THE
# 0                  FNNBTRIS                        QNB FINANSBANK A.S.
# 0                  TEBUTRIS                  TURK EKONOMI BANKASI A.S.
# 0                  TGBATRIS               TURKIYE GARANTI BANKASI A.S.
# 0                  TRHBTR2A    TURKIYE HALK BANKASI A.S. (HEAD OFFICE)
# 0                  TVBATR2A            TURKIYE VAKIFLAR BANKASI T.A.O.
# 0                  YAPITRIS                 YAPI VE KREDI BANKASI A.S.
# 0                  BBOGCOBB                            BANCO DE BOGOTA
# 0                  COLOCOBM                           BANCOLOMBIA S.A.
# 0                  BNMXMXMM              BANCO NACIONAL DE MEXICO S.A.
# 0                  BSCHESMM                       BANCO SANTANDER S.A.
# 0                  CITIUS33                              CITIBANK N.A.
#
#                                       Branch address Branch code  \
# 0                               7, Sveta Nedelya Sq.         XXX
# 0                        TRG BANA JOSIPA JELACICA 10         XXX
# 0                            50 ROTHSCHILD BOULEVARD         XXX
# 0                  KENCOM HOUSE, FLOOR 7, MOI AVENUE         XXX
# 0                                   BIJLMERDREEF 106         XXX
# 0                      UBA HOUSE, FLOOR 8, 57 MARINA         XXX
# 0                                     UL. ZELAZNA 32         XXX
# 0                                  UL. SENATORSKA 18         XXX
# 0                                    UL. PULAWSKA 15         XXX
# 0                                 BARITIU STREET 8 G         XXX
# 0          15 TROYE STREET, ABSA TOWER WEST, FLOOR 7         XXX
# 0     25 SAUER STREET, STANDARD BANK CENTRE, FLOOR 5         XXX
# 0       KRISTAL KULE BINASI, BUYUKDERE CAD. 215 SISL         XXX
# 0   SOKULLU CADDESI 7A-7B, SARAY MAHALLESI, UMRANIYE         XXX
# 0    LEVENT NISPETIYE MAH. AYTAR, CAD. NO.2 BESIKTAS         XXX
# 0              BARBAROS MAH. SEBBOY SOK. 4, FLOOR 19         XXX
# 0  SARAY MAHALLESI DR ADNAN BUYUKDENIZ, CADDESI N...         XXX
# 0        YAPI KREDI PLAZA, BUYUKDERE CADDESI, LEVENT         XXX
# 0                                  CALLE 36 NO. 7-47         XXX
# 0                          CARRERA 52 50-20, FLOOR 9         XXX
# 0       ACTUARIO ROBERTO MEDELLIN 800, COL. SANTA FE         XXX
# 0  CIUDAD GRUPO SANTANDER, EDIFICIO PAMPA, CAMINO...         XXX
# 0                               388 GREENWICH STREET         XXX
#
#                                        Bank name          City  \
# 0                       \nUNICREDIT BULBANK AD\n         SOFIA
# 0                        \nZAGREBACKA BANKA DD\n        ZAGREB
# 0                         \nBANK HAPOALIM B.M.\n      TEL AVIV
# 0                     \nKCB BANK KENYA LIMITED\n       NAIROBI
# 0                              \nING BANK N.V.\n     AMSTERDAM
# 0                 \nUNITED BANK FOR AFRICA PLC\n         LAGOS
# 0               \nBANK OCHRONY SRODOWISKA S.A.\n      WARSZAWA
# 0        \nMBANK S.A. (FORMERLY BRE BANK S.A.)\n      WARSZAWA
# 0                       \nPKO BANK POLSKI S.A.\n      WARSZAWA
# 0                    \nBANCA TRANSILVANIA S.A.\n   CLUJ-NAPOCA
# 0                          \nABSA BANK LIMITED\n  JOHANNESBURG
# 0  \nSTANDARD BANK OF SOUTH AFRICA LIMITED,THE\n  JOHANNESBURG
# 0                        \nQNB FINANSBANK A.S.\n      ISTANBUL
# 0                  \nTURK EKONOMI BANKASI A.S.\n      ISTANBUL
# 0               \nTURKIYE GARANTI BANKASI A.S.\n      ISTANBUL
# 0    \nTURKIYE HALK BANKASI A.S. (HEAD OFFICE)\n      ISTANBUL
# 0            \nTURKIYE VAKIFLAR BANKASI T.A.O.\n      ISTANBUL
# 0                 \nYAPI VE KREDI BANKASI A.S.\n      ISTANBUL
# 0                            \nBANCO DE BOGOTA\n        BOGOTA
# 0                           \nBANCOLOMBIA S.A.\n      MEDELLIN
# 0              \nBANCO NACIONAL DE MEXICO S.A.\n        MEXICO
# 0                       \nBANCO SANTANDER S.A.\n        MADRID
# 0                              \nCITIBANK N.A.\n      NEW YORK
#
#              Country
# 0       \nBulgaria\n
# 0        \nCroatia\n
# 0         \nIsrael\n
# 0          \nKenya\n
# 0    \nNetherlands\n
# 0        \nNigeria\n
# 0         \nPoland\n
# 0         \nPoland\n
# 0         \nPoland\n
# 0        \nRomania\n
# 0   \nSouth Africa\n
# 0   \nSouth Africa\n
# 0         \nTurkey\n
# 0         \nTurkey\n
# 0         \nTurkey\n
# 0         \nTurkey\n
# 0         \nTurkey\n
# 0         \nTurkey\n
# 0       \nColombia\n
# 0       \nColombia\n
# 0         \nMexico\n
# 0          \nSpain\n
# 0  \nUnited States\n

# %%
retrieved_missing.loc[:, ['Bank name', 'Country']] = \
    retrieved_missing.loc[:, ['Bank name', 'Country']].applymap(lambda x: x.strip())

retrieved_missing['swift_full'] = retrieved_missing['Swift code (8 characters)'] + retrieved_missing['Branch code']

retrieved_missing = \
    (retrieved_missing.rename({'Swift code (8 characters)': 'swift_short',
                               'Branch name': 'branch_name',
                               'Branch address': 'branch_address',
                               'Branch code': 'branch_code',
                               'Bank name': 'bank_name',
                               'City': 'city',
                               'Country': 'country'
                              }, axis=1)
     .loc[:, ['country', 'city', 'bank_name', 'branch_name',
              'branch_code', 'branch_address', 'swift_short', 'swift_full']]
    )

# %%
retrieved_missing = \
    (missing_address
     .drop(['bank_name', 'city', 'branch_name', 'branch_code', 'branch_address', 'swift_full'], axis=1)
     .merge(retrieved_missing, on='swift_short', how='left')
    )

# %%
detail_handled_missing = \
    (pd.concat([detail_with_swift_addr[detail_with_swift_addr.city.notnull()],
               retrieved_missing])
     .reset_index(drop=True)
     .drop('country', axis=1)
    )

# %%
detail_handled_missing
# Out:
#     Region    Bank Country  # of banks by country  \
# 0     EMEA  Czech Republic                    9.0
# 1     EMEA  Czech Republic                    NaN
# 2     EMEA  Czech Republic                    NaN
# 3     EMEA  Czech Republic                    NaN
# 4     EMEA  Czech Republic                    NaN
# ..     ...             ...                    ...
# 249  LATAM          Mexico                    NaN
# 250  LATAM           Spain                    2.0
# 251  LATAM           Spain                    NaN
# 252  LATAM           Spain                    NaN
# 253  LATAM   United States                    2.0
#
#                                Bank Name      Cash Type Currency       BIC  \
# 0                 Česká spořitelna, a.s.  Merchant Cash      CZK  GIBACZPX
# 1    Československá obchodní banka, a.s.  Merchant Cash      CZK  CEKOCZPP
# 2                        Fio banka, a.s.  Merchant Cash      CZK  FIOBCZPP
# 3                   Komerční banka, a.s.  Merchant Cash      CZK  KOMBCZPP
# 4                   Komerční banka, a.s.     Trade cash      CZK  KOMBCZPP
# ..                                   ...            ...      ...       ...
# 249       Banco Nacional de Mexico, S.A.     Trade Cash      MXN       NaN
# 250                 Banco Santander S.A.     Trade Cash      EUR       NaN
# 251                 Banco Santander S.A.     Trade Cash      USD       NaN
# 252                         Pershing LLC     Trade Cash      USD       NaN
# 253                       Citibank, N.A.     Trade Cash      USD       NaN
#
#      # of accounts swift_short                            bank_name  \
# 0                9    GIBACZPX                CESKA SPORITELNA A.S.
# 1                3    CEKOCZPP  CESKOSLOVENSKA OBCHODNI BANKA, A.S.
# 2                2    FIOBCZPP                      FIO BANKA, A.S.
# 3                2    KOMBCZPP                  KOMERCNI BANKA A.S.
# 4                1    KOMBCZPP                  KOMERCNI BANKA A.S.
# ..             ...         ...                                  ...
# 249              1    BNMXMXMM        BANCO NACIONAL DE MEXICO S.A.
# 250              1    BSCHESMM                 BANCO SANTANDER S.A.
# 251              1    BSCHESMM                 BANCO SANTANDER S.A.
# 252              1   PRSHUS33                                   NaN
# 253              1    CITIUS33                        CITIBANK N.A.
#
#                              branch_name      city branch_code  \
# 0                  CESKA SPORITELNA A.S.    PRAGUE         XXX
# 1    CESKOSLOVENSKA OBCHODNI BANKA, A.S.    PRAGUE         XXX
# 2                        FIO BANKA, A.S.    PRAGUE         XXX
# 3                    KOMERCNI BANKA A.S.    PRAGUE         XXX
# 4                    KOMERCNI BANKA A.S.    PRAGUE         XXX
# ..                                   ...       ...         ...
# 249        BANCO NACIONAL DE MEXICO S.A.    MEXICO         XXX
# 250                 BANCO SANTANDER S.A.    MADRID         XXX
# 251                 BANCO SANTANDER S.A.    MADRID         XXX
# 252                                  NaN       NaN         NaN
# 253                        CITIBANK N.A.  NEW YORK         XXX
#
#                                         branch_address   swift_full
# 0                                       OLBRACHTOVA 62  GIBACZPXXXX
# 1                                     RADLICKA 333/150  CEKOCZPPXXX
# 2         MILLENNIUM PLAZA, FLOOR 1, V CELNICI 1028/10  FIOBCZPPXXX
# 3                                        NA PRIKOPE 33  KOMBCZPPXXX
# 4                                        NA PRIKOPE 33  KOMBCZPPXXX
# ..                                                 ...          ...
# 249       ACTUARIO ROBERTO MEDELLIN 800, COL. SANTA FE  BNMXMXMMXXX
# 250  CIUDAD GRUPO SANTANDER, EDIFICIO PAMPA, CAMINO...  BSCHESMMXXX
# 251  CIUDAD GRUPO SANTANDER, EDIFICIO PAMPA, CAMINO...  BSCHESMMXXX
# 252                                                NaN          NaN
# 253                               388 GREENWICH STREET  CITIUS33XXX
#
# [254 rows x 15 columns]

# %%
# detail_handled_missing.to_excel('detail_all_done.xlsx', index=False)

# %% [markdown]
# ## Matching banks from web with summary by names (optional)

# %%
banks_info_df['name_from_wise'] = \
    (banks_info_df.name_from_wise
     .str.lower()
     .apply(lambda x: re.sub('[–,\.\(\)-]', '', x))
    )

# %%
banks_info_df
# Out:
#           swift                     name_from_wise   bank_country
# 0   BUINBGSFXXX           allianz bank bulgaria ad       bulgaria
# 0   BNPABGSXXXX         bnp paribas sasofia branch       bulgaria
# 0   BSBGBGSFXXX                          borica ad       bulgaria
# 1   BSBGBGSFIOP                          borica ad       bulgaria
# 0   NASBBGSFXXX      bulgarian development bank ad       bulgaria
# ..          ...                                ...            ...
# 3   ZFNBUS55SLC            zions bancorporation na  united states
# 4   ZFNBUS55SEA            zions bancorporation na  united states
# 0   ZURIUS44FAR  zurich american insurance company  united states
# 1   ZURIUS44XXX  zurich american insurance company  united states
# 2   ZURIUS44ZNA  zurich american insurance company  united states
#
# [6233 rows x 3 columns]

# %%
bic_data = bic_data.rename({'Region': 'region',
                            'Bank Country': 'bank_country',
                            '# of banks by country': 'n_banks_by_country',
                            '# of banks running': 'n_banks_running',
                            'Bank Name': 'bank_name',
                            '# of accounts': 'n_accounts'
                           }, axis = 1)

bic_data.bank_country = bic_data.bank_country.str.lower()

bic_data.bank_name = \
    (bic_data.bank_name
     .str.lower()
     .apply(lambda x: re.sub('[–,\.\(\)-]', '', x))
    )

# %%
bic_data.head()
# Out:
#   region    bank_country  n_banks_by_country  n_banks_running  \
# 0   EMEA        bulgaria                 1.0              1.0
# 1   EMEA         croatia                 1.0              2.0
# 2   EMEA  czech republic                 9.0              3.0
# 3   EMEA  czech republic                 NaN              4.0
# 4   EMEA  czech republic                 NaN              5.0
#
#                           bank_name  n_accounts
# 0              unicredit bulbank ad           1
# 1                  zagrebacka banka           2
# 2               česká spořitelna as           9
# 3  československá obchodní banka as           3
# 4                      fio banka as           2

# %%
def min_levenshtein_dist(banks_info_df, bank):
    
    max_swift_bank = ''
    max_swift_dist = float('inf')
    
    for bank_from_info_df, swift in zip(banks_info_df.name_from_wise, banks_info_df.swift):
        
        lev_dist = nltk.edit_distance(bank, bank_from_info_df)
        
        if lev_dist < max_swift_dist:
            max_swift_bank = bank_from_info_df
            max_swift_dist = lev_dist
            
    return pd.DataFrame({'bank_name': [bank],
                         'best_match': [max_swift_bank],
                         'letter_mismatch': [max_swift_dist],
                         'swift': [swift]
                        })

# %%
min_levenshtein_dist(banks_info_df, 'československá obchodní banka as')
# Out:
#                           bank_name                        best_match  \
# 0  československá obchodní banka as  ceskoslovenska obchodni banka as
#
#    letter_mismatch        swift
# 0                3  ZURIUS44XXX

# %%
store_similar = []

for country in bic_data.bank_country.unique():
    
    bic_data_country = bic_data.query('bank_country == @country')
    banks_info_country = banks_info_df.query('bank_country == @country')
    
    for bank in bic_data_country.bank_name:
        store_similar.append(min_levenshtein_dist(banks_info_country, bank))
    
    print(f'found similars for {country}')

matches = pd.concat(store_similar)
# Out:
# found similars for bulgaria
# found similars for croatia
# found similars for czech republic
# found similars for united kingdom
# found similars for hungary
# found similars for israel
# found similars for kenya
# found similars for netherlands
# found similars for nigeria
# found similars for poland
# found similars for romania
# found similars for russia
# found similars for slovakia
# found similars for south africa
# found similars for turkey
# found similars for argentina
# found similars for chile
# found similars for colombia
# found similars for mexico
# found similars for panama
# found similars for peru
# found similars for spain
# found similars for united states

# %%
matches.query('letter_mismatch > 3')
# Out:
#                              bank_name  \
# 0                             mbank sa
# 0             ppro payment services sa
# 0               unicredit bank hungary
# 0                           bank leumi
# 0            citibank na israel branch
# 0                            cellulant
# 0                                  kcb
# 0                          equity bank
# 0                 citibank nigeria ltd
# 0             first city monument bank
# 0                        alior bank sa
# 0                        bank handlowy
# 0                     bank nowy bfg sa
# 0  bank polska kasa opieki sa pekao sa
# 0                         idea bank sa
# 0                             mbank sa
# 0                         mbank sa bre
# 0                             payoneer
# 0                            sandander
# 0      brd  groupe société générale sa
# 0                ing bank nv bucharest
# 0                        paypal europe
# 0             unicredit tiriac bank sa
# 0               binbank credit systems
# 0                      ing bank russia
# 0                  mgtu bank of russia
# 0           qiwi bank evroset&svyaznoi
# 0            pay solutions as besteron
# 0                            absa bank
# 0                  first national bank
# 0                        standard bank
# 0              asya katilim bankasi as
# 0                        finansbank as
# 0                    tc ziraat bankasi
# 0              turkiye halk bankasi as
# 0                          ci banco sa
# 0         citibank na argentina branch
# 0                     banco itau chile
# 0                  banco davivienda sa
# 0    banco red multibanca colpatria sa
# 0                                 bbva
# 0         banco mercantil del norte sa
# 0            banco santander mexico sa
# 0                         pershing llc
#
#                                   best_match  letter_mismatch        swift
# 0                                air bank as                6  ZENGCZPPXXX
# 0                         hsbc fund services               13  ZURIGB2LEND
# 0                 unicredit bank hungary zrt                4  BACXHUHBINM
# 0                             bank of israel                9  UNBKILITINT
# 0                   union bank of israel ltd               13  UNBKILITINT
# 0                                hfc limited                9  VICMKENAXXX
# 0                                hfc limited               10  VICMKENAXXX
# 0                             prime bank ltd                9  VICMKENAXXX
# 0                   citibank nigeria limited                4  ZEPCNGLAXXX
# 0           first city monument bank limited                8  ZEPCNGLAXXX
# 0                               plus bank sa                4  VOWAPLP9XXX
# 0                                bank bph sa                8  VOWAPLP9XXX
# 0                                bank bph sa                7  VOWAPLP9XXX
# 0  bank polska kasa opieki sa  bank pekao sa                6  VOWAPLP9XXX
# 0                               nest bank sa                4  VOWAPLP9XXX
# 0                                bank bph sa                5  VOWAPLP9XXX
# 0                                bank bph sa                7  VOWAPLP9XXX
# 0                                   kdpw ccp                8  VOWAPLP9XXX
# 0                                    kdpw sa                8  VOWAPLP9XXX
# 0            brd  groupe societe generale sa                4  EGNAROBXXXX
# 0               ing bank nv bucharest branch                7  EGNAROBXXXX
# 0                                   superbet               10  EGNAROBXXXX
# 0                          unicredit bank sa                7  EGNAROBXXXX
# 0                     interbank credit union               11  TCZBRUMMXXX
# 0                         eximbank of russia                7  TCZBRUMMXXX
# 0                         eximbank of russia                5  TCZBRUMMXXX
# 0                           bank ''rossiya''               15  TCZBRUMMXXX
# 0                           sia slovakia sro               17  WUSTSKBAXXX
# 0                              albaraka bank                5  CEQPZAJJXXX
# 0                            vbs mutual bank                9  CEQPZAJJXXX
# 0                              albaraka bank                7  CEQPZAJJXXX
# 0                   pasha yatirim bankasi as                4  ZOHLTRISXXX
# 0                               fibabanka as                4  ZOHLTRISXXX
# 0                             burgan bank as                9  ZOHLTRISXXX
# 0                      turkiye is bankasi as                4  ZOHLTRISXXX
# 0                                citibank na                5  SECTARB1XXX
# 0                     hsbc bank argentina sa               13  SECTARB1XXX
# 0                             banco de chile                4  TEGECLR1XXX
# 0                         banco pichincha sa                8  VABCCOBMXXX
# 0                    scotiabank colpatria sa               14  VABCCOBMXXX
# 0                                 bavaria sa                7  VABCCOBMXXX
# 0                   banco keb hana mexico sa               14  VWAGMXMMXXX
# 0                   banco keb hana mexico sa                8  VWAGMXMMXXX
# 0                                    puig sl                7  ZURIESBBXXX

# %%
banks_info_df.query('name_from_wise.str.contains("handlowy")')
# Out:
#          swift                name_from_wise bank_country
# 0  CITIPLPXXXX  bank handlowy w warszawie sa       poland
# 1  CITIPLPXCCH  bank handlowy w warszawie sa       poland

# %% [markdown]
# ### Perform match search with masking by separate words

# %%
def replace_letters(word):
    
    for old, new in {'č': 'c', 'á': 'a', 'ř': 'r', 'í': 'i'}.items():
        word = word.replace(old, new)
    
    return word

# %%
bic_data['bank_name'] = \
    bic_data.bank_name.apply(lambda x: replace_letters(x))

# %%
bic_data['bank_name_split'] = \
    bic_data.bank_name.str.split()

# %%
banks_info_df
# Out:
#           swift                     name_from_wise   bank_country swift_cut
# 0   BUINBGSFXXX           allianz bank bulgaria ad       bulgaria  BUINBGSF
# 0   BNPABGSXXXX         bnp paribas sasofia branch       bulgaria  BNPABGSX
# 0   BSBGBGSFXXX                          borica ad       bulgaria  BSBGBGSF
# 1   BSBGBGSFIOP                          borica ad       bulgaria  BSBGBGSF
# 0   NASBBGSFXXX      bulgarian development bank ad       bulgaria  NASBBGSF
# ..          ...                                ...            ...       ...
# 3   ZFNBUS55SLC            zions bancorporation na  united states  ZFNBUS55
# 4   ZFNBUS55SEA            zions bancorporation na  united states  ZFNBUS55
# 0   ZURIUS44FAR  zurich american insurance company  united states  ZURIUS44
# 1   ZURIUS44XXX  zurich american insurance company  united states  ZURIUS44
# 2   ZURIUS44ZNA  zurich american insurance company  united states  ZURIUS44
#
# [6233 rows x 4 columns]

# %%
banks_info_df['swift_cut'] = \
    banks_info_df.swift.apply(lambda x: x[:-3])

banks_no_dupl = banks_info_df.drop_duplicates(subset=['swift_cut'])

# %%
banks_no_dupl
# Out:
#           swift                     name_from_wise   bank_country swift_cut
# 0   BUINBGSFXXX           allianz bank bulgaria ad       bulgaria  BUINBGSF
# 0   BNPABGSXXXX         bnp paribas sasofia branch       bulgaria  BNPABGSX
# 0   BSBGBGSFXXX                          borica ad       bulgaria  BSBGBGSF
# 0   NASBBGSFXXX      bulgarian development bank ad       bulgaria  NASBBGSF
# 0   BNBGBGSFXXX            bulgarian national bank       bulgaria  BNBGBGSF
# ..          ...                                ...            ...       ...
# 0   XERXUS31XXX                  xerox corporation  united states  XERXUS31
# 0   YIFTUS32XXX               yisrael family trust  united states  YIFTUS32
# 0   TRWAUS33XXX               zf automotive us inc  united states  TRWAUS33
# 0   ZFNBUS55LAX            zions bancorporation na  united states  ZFNBUS55
# 0   ZURIUS44FAR  zurich american insurance company  united states  ZURIUS44
#
# [4234 rows x 4 columns]

# %%
def check_levenshtein_for_result(result, name_lst):
    
    best_match = ''
    mismatch_cnt = float('inf')
    
    for name in result.name_from_wise:
        lev = nltk.edit_distance(name, ' '.join(name_lst))
        
        if lev < mismatch_cnt:
            mismatch_cnt = lev
            best_match = name
    
    res_df = result.query('name_from_wise == @best_match')
    res_df['name_from_xlsx'] = ' '.join(name_lst)
    res_df['mismatch_cnt'] = mismatch_cnt
    
    return res_df

# %%
def search_by_word(banks_info_df, country, name_lst):
    
    store_lev_checks = []
    
    for word in name_lst:
        
        word = f' {word} |^{word} | {word}$'
        
        banks_info_country = banks_info_df.query('bank_country == @country')
        result = banks_info_country.query('name_from_wise.str.contains(@word)')
        
        if result.shape[0] == 1:
            result['name_from_xlsx'] = ' '.join(name_lst)
            result['mismatch_cnt'] = 0
            return result
        
        elif result.shape[0] >= 2:
            
            lev_one_word = check_levenshtein_for_result(result, name_lst)
            store_lev_checks.append(lev_one_word)
    
    if store_lev_checks:
        mismatches = pd.concat(store_lev_checks)
        return mismatches.query('mismatch_cnt == mismatch_cnt.min()')
    
    return pd.DataFrame({'swift': [],
                         'name_from_wise': [],
                         'bank_country': [],
                         'swift_cut': [],
                         'name_from_xlsx': [],
                         'mismatch_cnt': []
                        })

# %%
search_by_word(banks_no_dupl, no_swift_1.bank_country.iloc[16], no_swift_1.bank_name_split.iloc[16])
# Out:
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
#          swift                 name_from_wise bank_country swift_cut  \
# 0  FNNBROBUXXX  credit europe bank romania sa      romania  FNNBROBU
#
#   name_from_xlsx  mismatch_cnt
# 0  paypal europe            22

# %%
store_search = []

for country in bic_data.bank_country.unique():
    
    for name in bic_data.query('bank_country == @country').bank_name_split:
        
        store_search.append(search_by_word(banks_no_dupl, country, name))
        
        
matches = pd.concat(store_search).drop_duplicates().drop('swift', axis=1)
# Out:
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-480-cfacb835e8b0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt
# <ipython-input-523-fbef0394c37f>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
# <ipython-input-523-fbef0394c37f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['mismatch_cnt'] = 0
# <ipython-input-480-cfacb835e8b0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['mismatch_cnt'] = mismatch_cnt

# %%
matches.mismatch_cnt.value_counts().sort_index()
# Out:
# 0.0     81
# 1.0      4
# 2.0      1
# 3.0      4
# 4.0      3
# 5.0      3
# 7.0      3
# 8.0      3
# 11.0     2
# 13.0     2
# 17.0     1
# 22.0     1
# Name: mismatch_cnt, dtype: int64

# %%
matches = \
    (matches
     .rename({'swift_cut': 'swift_short', 'name_from_xlsx': 'initial_name'}, axis=1)
     .loc[:, ['bank_country', 'initial_name', 'name_from_wise', 'swift_short', 'mismatch_cnt']]
    )

# %%
banks_with_swifts = \
    bic_data.merge(matches.loc[:, ['name_from_wise', 'initial_name', 'swift_short', 'mismatch_cnt']],
                   left_on='bank_name',
                   right_on='initial_name',
                   how='left').drop(['initial_name', 'bank_name_split'], axis=1)

# %%
banks_with_swifts.to_excel('banks_with_swifts.xlsx', index=False)

# %%
no_swift_1 = bic_data.query('swift_cut.isnull()').drop(['name_from_wise', 'name_from_xlsx', 'swift_cut'], axis=1)

# %%
no_swift_1
# Out:
#     region    bank_country  n_banks_by_country  n_banks_running  \
# 7     EMEA  czech republic                 NaN              8.0
# 11    EMEA  united kingdom                 1.0             12.0
# 12    EMEA         hungary                 2.0             13.0
# 17    EMEA           kenya                 2.0             18.0
# 21    EMEA     netherlands                 NaN             22.0
# 23    EMEA         nigeria                 NaN             24.0
# 28    EMEA         nigeria                 NaN             29.0
# 33    EMEA          poland                 NaN             34.0
# 36    EMEA          poland                 NaN             37.0
# 40    EMEA          poland                 NaN             41.0
# 44    EMEA          poland                 NaN             45.0
# 45    EMEA          poland                 NaN             46.0
# 46    EMEA          poland                 NaN             47.0
# 48    EMEA         romania                 NaN             49.0
# 50    EMEA         romania                 NaN             51.0
# 51    EMEA         romania                 NaN             52.0
# 54    EMEA         romania                 NaN             55.0
# 60    EMEA          russia                 NaN             61.0
# 61    EMEA          russia                 NaN             62.0
# 62    EMEA          russia                 NaN             63.0
# 64    EMEA          russia                 NaN             65.0
# 65    EMEA          russia                 NaN             66.0
# 67    EMEA    south africa                 5.0             68.0
# 68    EMEA    south africa                 NaN             69.0
# 71    EMEA    south africa                 NaN             72.0
# 73    EMEA          turkey                 NaN             74.0
# 78    EMEA          turkey                 NaN             79.0
# 80    EMEA          turkey                 NaN             81.0
# 83    EMEA          turkey                 NaN             84.0
# 87   LATAM       argentina                 NaN             88.0
# 90   LATAM           chile                 1.0             91.0
# 91   LATAM        colombia                 7.0             92.0
# 92   LATAM        colombia                 NaN             93.0
# 93   LATAM        colombia                 NaN             94.0
# 95   LATAM        colombia                 NaN             96.0
# 99   LATAM          mexico                 NaN            100.0
# 100  LATAM          mexico                 NaN            101.0
# 102  LATAM          mexico                 NaN            103.0
# 106  LATAM           spain                 2.0            107.0
# 107  LATAM           spain                 NaN            108.0
#
#                              bank_name  n_accounts  \
# 7                 moneta money bank as           2
# 11            ppro payment services sa           1
# 12                       otp bank nyrt           5
# 17                           cellulant           1
# 21                         ing bank nv          29
# 23           first bank of nigeria ltd           2
# 28                     zenith bank plc          13
# 33                    bank nowy bfg sa           7
# 36          bnp paribas bank polska sa           5
# 40                  ing bank śląski sa          20
# 44                            payoneer           1
# 45                  pko bank polski sa          14
# 46                           sandander          13
# 48          banca comerciala romana sa           2
# 50     brd  groupe société générale sa           8
# 51       credit europe bank romania sa          26
# 54                       paypal europe           1
# 60                                 cbr           1
# 61                     ing bank russia          13
# 62                 mgtu bank of russia           4
# 64               russian standart bank           1
# 65                            vtb bank           2
# 67                           absa bank          10
# 68                   absa bank limited           3
# 71                       standard bank           3
# 73             asya katilim bankasi as           2
# 78                   tc ziraat bankasi           2
# 80   turkiye finans katilim bankasi as           1
# 83               turkiye is bankasi as           5
# 87                         ci banco sa           2
# 90                    banco itau chile           3
# 91                 banco davivienda sa           5
# 92                  banco de bogota sa           1
# 93               banco de occidente sa           3
# 95                      bancolombia sa           4
# 99         banco nacional de mexico sa           1
# 100          banco santander mexico sa           3
# 102                        ci banco sa           1
# 106                 banco santander sa           2
# 107                       pershing llc           1
#
#                              bank_name_split
# 7                  [moneta, money, bank, as]
# 11             [ppro, payment, services, sa]
# 12                         [otp, bank, nyrt]
# 17                               [cellulant]
# 21                           [ing, bank, nv]
# 23           [first, bank, of, nigeria, ltd]
# 28                       [zenith, bank, plc]
# 33                     [bank, nowy, bfg, sa]
# 36          [bnp, paribas, bank, polska, sa]
# 40                   [ing, bank, śląski, sa]
# 44                                [payoneer]
# 45                   [pko, bank, polski, sa]
# 46                               [sandander]
# 48           [banca, comerciala, romana, sa]
# 50      [brd, groupe, société, générale, sa]
# 51       [credit, europe, bank, romania, sa]
# 54                          [paypal, europe]
# 60                                     [cbr]
# 61                       [ing, bank, russia]
# 62                  [mgtu, bank, of, russia]
# 64                 [russian, standart, bank]
# 65                               [vtb, bank]
# 67                              [absa, bank]
# 68                     [absa, bank, limited]
# 71                          [standard, bank]
# 73              [asya, katilim, bankasi, as]
# 78                     [tc, ziraat, bankasi]
# 80   [turkiye, finans, katilim, bankasi, as]
# 83                [turkiye, is, bankasi, as]
# 87                           [ci, banco, sa]
# 90                      [banco, itau, chile]
# 91                   [banco, davivienda, sa]
# 92                   [banco, de, bogota, sa]
# 93                [banco, de, occidente, sa]
# 95                         [bancolombia, sa]
# 99         [banco, nacional, de, mexico, sa]
# 100           [banco, santander, mexico, sa]
# 102                          [ci, banco, sa]
# 106                   [banco, santander, sa]
# 107                          [pershing, llc]

# %%
search_by_word(banks_no_dupl, no_swift_1.bank_country.iloc[2], no_swift_1.bank_name_split.iloc[2])
# Out:
# <ipython-input-411-c195483946ec>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)
#          swift        name_from_wise bank_country swift_cut name_from_xlsx
# 0  OTPVHUHBXXX          otp bank plc      hungary  OTPVHUHB  otp bank nyrt
# 0  OTPJHUHBXXX  otp mortgagebank ltd      hungary  OTPJHUHB  otp bank nyrt

# %%
store_search = []

for country in no_swift_1.bank_country.unique():
    
    for name in no_swift_1.query('bank_country == @country').bank_name_split:
        
        store_search.append(search_by_word(banks_no_dupl, country, name))
        
        
matches_2 = pd.concat(store_search)
# Out:
# <ipython-input-411-c195483946ec>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['name_from_xlsx'] = ' '.join(name_lst)

# %%
matches_2
# Out:
#                            bank_name                         best_match  \
# 0               moneta money bank as               moneta money bank as
# 0           ppro payment services sa          easy payment services ltd
# 0                                NaN                                NaN
# 0                                NaN                                NaN
# 0                          cellulant                          bell bank
# 0                        ing bank nv                        ing bank nv
# 0                                NaN                                NaN
# 0                                NaN                                NaN
# 0                                NaN                                NaN
# 0                                NaN                                NaN
# 0                   bank nowy bfg sa                        bank bph sa
# 0         bnp paribas bank polska sa         bnp paribas bank polska sa
# 0                                NaN                                NaN
# 0                                NaN                                NaN
# 0                           payoneer                       payoneer inc
# 0                 pko bank polski sa                 pko bank polski sa
# 0                          sandander                           unilever
# 0         banca comerciala romana sa         banca comerciala romana sa
# 0     brd groupe société générale sa    brd  groupe societe generale sa
# 0                                NaN                                NaN
# 0                                NaN                                NaN
# 0                      paypal europe                         paypal inc
# 0                                cbr                              vebrf
# 0                    ing bank russia                        ing bank nv
# 0                mgtu bank of russia                 eximbank of russia
# 0              russian standart bank              russian standard bank
# 0                                NaN                                NaN
# 0                                NaN                                NaN
# 0                          absa bank                           alfabank
# 0                  absa bank limited                  absa bank limited
# 0                      standard bank                      avangard bank
# 0            asya katilim bankasi as           pasha yatirim bankasi as
# 0                  tc ziraat bankasi                  tc ziraat bankasi
# 0  turkiye finans katilim bankasi as  turkiye finans katilim bankasi as
# 0              turkiye is bankasi as              turkiye is bankasi as
# 0                        ci banco sa                         cibanco sa
# 0                   banco itau chile                     banco de chile
# 0                banco davivienda sa                banco davivienda sa
# 0                 banco de bogota sa                 banco de bogota sa
# 0              banco de occidente sa                 banco de occidente
# 0                     bancolombia sa                     bancolombia sa
# 0        banco nacional de mexico sa        banco nacional de mexico sa
# 0          banco santander mexico sa             banco santander rio sa
# 0                        ci banco sa                         cibanco sa
# 0                 banco santander sa                 banco santander sa
# 0                       pershing llc                       pershing llc
#
#    letter_mismatch        swift                     name_from_wise  \
# 0              0.0  ZURIUS44FAR                                NaN
# 0              7.0  ZURIUS44FAR                                NaN
# 0              NaN  OTPVHUHBXXX                       otp bank plc
# 0              NaN  OTPJHUHBXXX               otp mortgagebank ltd
# 0              4.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              NaN  FBNINGLAGCS          first bank of nigeria ltd
# 0              NaN  FCMBNGLAWEB   first city monument bank limited
# 0              NaN  ZEIBNGLA013                    zenith bank plc
# 0              NaN  ZEPCNGLAXXX  zenith pensions custodian limited
# 0              7.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              NaN  INGBPLPHXXX             ing bank hipoteczny sa
# 0              NaN  INGBPLPWXXX                 ing bank slaski sa
# 0              4.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              6.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              5.0  ZURIUS44FAR                                NaN
# 0              NaN  BSEAROBUXXX    credit agricole bank romania sa
# 0              NaN  FNNBROBUXXX      credit europe bank romania sa
# 0              6.0  ZURIUS44FAR                                NaN
# 0              3.0  ZURIUS44FAR                                NaN
# 0              6.0  ZURIUS44FAR                                NaN
# 0              5.0  ZURIUS44FAR                                NaN
# 0              1.0  ZURIUS44FAR                                NaN
# 0              NaN  VTCARUMMXXX                    jsc vtb capital
# 0              NaN  VTBRRUM2KH3                      vtb bank pjsc
# 0              3.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              3.0  ZURIUS44FAR                                NaN
# 0              4.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              1.0  ZURIUS44FAR                                NaN
# 0              4.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              3.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              4.0  ZURIUS44FAR                                NaN
# 0              1.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
# 0              0.0  ZURIUS44FAR                                NaN
#
#   bank_country swift_cut                 name_from_xlsx
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0      hungary  OTPVHUHB                  otp bank nyrt
# 0      hungary  OTPJHUHB                  otp bank nyrt
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0      nigeria  FBNINGLA      first bank of nigeria ltd
# 0      nigeria  FCMBNGLA      first bank of nigeria ltd
# 0      nigeria  ZEIBNGLA                zenith bank plc
# 0      nigeria  ZEPCNGLA                zenith bank plc
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0       poland  INGBPLPH             ing bank śląski sa
# 0       poland  INGBPLPW             ing bank śląski sa
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0      romania  BSEAROBU  credit europe bank romania sa
# 0      romania  FNNBROBU  credit europe bank romania sa
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0       russia  VTCARUMM                       vtb bank
# 0       russia  VTBRRUM2                       vtb bank
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
# 0          NaN       NaN                            NaN
